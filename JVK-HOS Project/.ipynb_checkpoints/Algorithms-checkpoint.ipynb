# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.grid_search import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.cross_validation import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
from sklearn.base import TransformerMixin
from sklearn.feature_selection import SelectKBest
import itertools
from sklearn.linear_model import SGDRegressor
from sklearn.cross_validation import KFold
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import operator
plt.style.use('ggplot')
# %matplotlib inline


import pandas
import numpy as np
from sklearn.grid_search import GridSearchCV
dfNotNull = pandas.read_csv('Long.csv')
dfNotNull = dfNotNull[dfNotNull.noCPT == 0]
dfNotNull.head()

print "Average Time:"
print dfNotNull.TotalTimeMin.mean()

print "procedure Value Counts" 
print dfNotNull.Procedure3.value_counts()
# Out:
# Average Time:
# 34.1785714286
# procedure Value Counts
# Lumbar Radiofrequency                    221
# Lumbar ESI                               141
# Lumbar Medial Branch Block               113
# Facet Joint Injection                     69
# Cervical/Thoracic Medial Branch Block     42
# Spinal Cord Stimulator                    26
# Cervical/Thoracic ESI                     25
# Cervical/Thoracic Radiofrequency          18
# Joint Injection, other                     9
# Nerve Block                                7
# Not Assigned                               1
# Name: Procedure3, dtype: int64

# %%
print "get null scores"

numFolds = 5
y = dfNotNull['TotalTimeMin']
X = dfNotNull['Procedure4']
abse =[]
sqrd =[]

import CleanDefs
for i in range(1,5):
    kf = KFold(len(X), numFolds, shuffle=True)
    for train_indices, test_indices in kf:
        features_train = X[train_indices]
        response_train= y[train_indices]
        features_test = X[test_indices]
        response_test = y[test_indices]

        dfT = pandas.DataFrame()
        dfT['Procedure4'] = features_train
        dfT['TotalTimeMin']= response_train
        dfT['AverageProcTime']=dfT['TotalTimeMin'].mean()
        
        dfR = pandas.DataFrame()
        dfR['Procedure4'] = features_test
        dfR['TotalTimeMin']= response_test
        dfR['AverageProcTime']=dfT['TotalTimeMin'].mean()

        y1 = dfR['TotalTimeMin']
        X1 = dfR['AverageProcTime']
        differences = (y1 - X1).abs()
        abse += [differences.mean()]
        sqrd += [(differences**2).mean()]
        
        
print "Total Average Null:"
print np.sqrt(np.array(sqrd)).mean()
print np.array(abse).mean()



numFolds = 5

y = dfNotNull['TotalTimeMin']
X = dfNotNull['Procedure4']

abse =[]
sqrd =[]
for i in range(1,5):
    kf = KFold(len(X), numFolds, shuffle=True)
    smlSqrd =[]
    for train_indices, test_indices in kf:
        features_train = X[train_indices]
        response_train= y[train_indices]
        features_test = X[test_indices]
        response_test = y[test_indices]

        dfT = pandas.DataFrame()
        dfT['Procedure4'] = features_train
        dfT['TotalTimeMin']= response_train
        dfT['AverageProcTime']=dfT['Procedure4'].apply(lambda x: CleanDefs.createProcAvgs(x,dfT) )
        dfR = pandas.DataFrame()
        dfR['Procedure4'] = features_test
        dfR['TotalTimeMin']= response_test
        dfR['AverageProcTime']=dfR['Procedure4'].apply(lambda x: CleanDefs.createProcAvgs(x,dfT) )
        
        y1 = dfR['TotalTimeMin']
        X1 = dfR['AverageProcTime']
        differences = (y1 - X1).abs()
        abse += [differences.mean()]
        
        smlSqrd += [(differences**2).mean()]
    #print np.array([smlSqrd])
    sqrd += [np.sqrt(np.array(smlSqrd)).mean()]
print "Procedure Average Null:"
print np.array(abse).mean()

print np.array(sqrd).mean()
# Out:
# get null scores
# Total Average Null:
# 17.0352177771
# 11.0595509957
# Procedure Average Null:
# 6.62104695097
# 10.234851065

# %%
print "Different Features sets and corr plots"

Procedure3feat = ['Lumbar Radiofrequency', 'Cervical/Thoracic Radiofrequency', 'Facet Joint Injection', 'Cervical/Thoracic ESI'] 
Procedure3feat += ['Cervical/Thoracic Medial Branch Block', 'Spinal Cord Stimulator', 'Nerve Block', 'Lumbar Medial Branch Block']
Procedure3feat += ['Lumbar ESI', 'Joint Injection, other']
                  
Procedure4feat = ['Radiofrequency','ESI', 'Medial Branch Block', 'Injection',  'Nerve Block 2','Spinal Cord Stimulator 2']
                  
ClassFeat = ['3', 'Gender', '1r']

NonScaledContfeat  = ['Age','BMI','HealthCodesLen', 'SurgicalHistoryLen']

ScaledContfeat  = ['AgeScaled','BMIScaled','HealthCodesLenScaled', 'SurgicalHistoryLenScaled']

HealthCodes = ['M54', 'G25', 'M51', 'M50', 'M53', 'G54', 'E78', 'C177', 'D51', 'G3', 'G2', 'N28', 'I73', 'M48', 'M43', 'M41', 'M46', 'M47', 'Z79', 'F32', 'G57', 'D68', 'Q76', 'Z72', 'Y92', 'T85', 'I69', 'C182', 'M32', 'G40','F03', 'G47', 'C178', 'Y83', 'Y84', 'I50', 'C45', 'E05', 'M25', 'F12', 'F17', 'K74', 'I48', 'I42', 'C79', 'I25','E11', 'J45', 'C6', 'L40', 'E21', 'C189', 'N1', 'M96', 'M10', 'M12', 'M19', 'F41', 'Z01', 'J44', 'M79', 'J43', 'Z80','I89', 'Z85', 'Z87', 'Z86', 'Z89', 'Z88', 'C95', 'I1', 'N40', 'M84', 'M81', 'M06', 'G95', 'G90', 'R53', 'R56', 'E06', 'E07', 'K21', 'E03', 'Z96', 'Z94', 'Z95', 'Z92', 'Z90', 'Z91', 'Z98', 'E89', 'C81', 'G82', 'R26', 'Q61']

HealthCodes2 = ['C', 'E', 'D', 'G', 'F', 'I', 'K', 'J', 'M', 'L', 'N', 'Q', 'R', 'T', 'Y', 'Z']

CPTcodes = ['20610', '64479', '64640', '63650', '64483', '64480', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096']

InsuranceCodes = ['BLUE CROSS','BLUE SHIELD','MEDICARE']
print dfNotNull.TotalTimeMin.mean()
sigCodesList = []
for i in HealthCodes:
    if len(dfNotNull[dfNotNull[i] == 1]) > 20 and abs(dfNotNull[dfNotNull[i] == 1].TotalTimeMin.mean() - 34.18) >=3 :
        print i + " = " + str(dfNotNull[dfNotNull[i] == 1].TotalTimeMin.mean()) + ", " + str(len(dfNotNull[dfNotNull[i] == 1]))
        sigCodesList += [i]
        

for i in HealthCodes2:
    if len(dfNotNull[dfNotNull[i] == 1]) > 20 and abs(dfNotNull[dfNotNull[i] == 1].TotalTimeMin.mean() - 34.18) >=0 :
        print i + " = " + str(dfNotNull[dfNotNull[i] == 1].TotalTimeMin.mean()) + ", " + str(len(dfNotNull[dfNotNull[i] == 1]))
        sigCodesList += [i]
cptCodesList = []
for i in CPTcodes:
    if len(dfNotNull[dfNotNull[i] == 1]) > 0 and abs(dfNotNull[dfNotNull[i] == 1].TotalTimeMin.mean() - 34.18) >=0 :
        print i + " = " + str(dfNotNull[dfNotNull[i] == 1].TotalTimeMin.mean()) + ", " + str(len(dfNotNull[dfNotNull[i] == 1]))
        cptCodesList += [i]
    
    
feature_cols = Procedure3feat + Procedure4feat + ClassFeat + NonScaledContfeat + sigCodesList
corrDF = dfNotNull[ NonScaledContfeat + ['TotalTimeMin']]
corrDF.corr()
print sigCodesList
# Out:
# Different Features sets and corr plots
# 34.1785714286
# F32 = 42.347826087, 23
# F17 = 31.0612244898, 98
# M96 = 43.0961538462, 104
# Z85 = 40.0833333333, 36
# Z87 = 37.2727272727, 22
# Z95 = 37.5675675676, 37
# E = 33.864628821, 229
# G = 40.1857142857, 70
# F = 33.496, 125
# I = 34.5345454545, 275
# J = 35.4285714286, 84
# M = 34.1785714286, 672
# Z = 34.4704225352, 355
# 20610 = 27.6666666667, 3
# 64479 = 30.0, 1
# 64640 = 50.0, 1
# 63650 = 93.32, 25
# 64483 = 23.9052631579, 190
# 64480 = 30.0, 1
# 64634 = 39.5961538462, 52
# 64635 = 41.7794871795, 195
# 64636 = 41.7794871795, 195
# 64484 = 23.90625, 160
# 20605 = 29.0, 1
# 63685 = 113.0, 16
# 63688 = 89.0, 1
# 62311 = 28.0909090909, 11
# 62310 = 25.0952380952, 42
# 63661 = 89.0, 1
# 64494 = 27.8405797101, 138
# 64495 = 28.4942528736, 87
# 64633 = 39.5961538462, 52
# 64490 = 30.2203389831, 59
# 64491 = 30.2857142857, 56
# 64492 = 29.3076923077, 39
# 64493 = 27.8967741935, 155
# 64450 = 33.0, 1
# 27096 = 18.8, 5
# ['F32', 'F17', 'M96', 'Z85', 'Z87', 'Z95', 'E', 'G', 'F', 'I', 'J', 'M', 'Z']

# %%
print """
Run Linear Regression Train-Test Split ****
"""
feature_cols += ['Spinal Cord Stimulator']
X = dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']


abse = []
sqrd = []
for i in range(1,2):
    features_train, features_test, response_train, response_test \
    = train_test_split(X, y, random_state=4)
    # instantiate and fit

    
    linreg = LinearRegression()
    linreg.fit(features_train, response_train)
    print type(features_test)
    predictionDF = pandas.DataFrame()
    predictionDF['Predictions'] = linreg.predict(features_test)
    predictionDF['Actual'] = response_test.values
    differences = (predictionDF['Predictions'] - predictionDF['Actual']).abs()
    abse += [differences.mean()]
    sqrd += [(differences**2).mean()]
print np.array(abse).mean()
print np.sqrt(np.array(sqrd)).mean() 
f = lambda x:int(round(x/15.)*15)


print predictionDF.head(15)
print zip(feature_cols,linreg.coef_)
# Out:
# Run Linear Regression Train-Test Split ****
#
# <class 'pandas.core.frame.DataFrame'>
# 6.22997782397
# 9.69361310937
#     Predictions  Actual
# 0     28.180061      42
# 1     40.910488      43
# 2     21.091196      25
# 3     23.229159      25
# 4     25.669731      25
# 5     30.092353      23
# 6     29.671896      33
# 7     34.666338      26
# 8     17.688884      18
# 9     37.699087      48
# 10    23.458718      21
# 11    18.195313      20
# 12    43.622502      26
# 13    24.650495      20
# 14    20.079639      18
# [('Lumbar Radiofrequency', -11.334673842258063), ('Cervical/Thoracic Radiofrequency', -20.769004455890254), ('Facet Joint Injection', -16.89220070223994), ('Cervical/Thoracic ESI', -20.991332207287069), ('Cervical/Thoracic Medial Branch Block', -17.545875816891982), ('Spinal Cord Stimulator', 2.9516113522738658), ('Nerve Block', -29.828413063867941), ('Lumbar Medial Branch Block', -19.470000091540502), ('Lumbar ESI', -20.828326210873485), ('Joint Injection, other', -22.414126147092059), ('Radiofrequency', -32.103678298147329), ('ESI', -41.819658418162618), ('Medial Branch Block', -37.015875908431873), ('Injection', -39.306326849331221), ('Nerve Block 2', -29.828413063868247), ('Spinal Cord Stimulator 2', 2.951611352274635), ('3', 2.1882429262339045), ('Gender', 0.041223436659434842), ('1r', -2.727784619041739), ('Age', 0.036977581659024261), ('BMI', -0.020299306976374151), ('HealthCodesLen', 0.12512035167507496), ('SurgicalHistoryLen', 0.28581239447923823), ('F32', 3.9998196625977602), ('F17', -1.2577722200566228), ('M96', -0.32556214501557657), ('Z85', -4.7515483147937472), ('Z87', -1.2717932058310266), ('Z95', 0.55820374148769214), ('E', -0.64605546514772527), ('G', 2.0183663604460813), ('F', 0.17762923012133847), ('I', -1.461285531558433), ('J', -0.10624552989714076), ('M', 0.0), ('Z', -0.027828553166451719), ('Spinal Cord Stimulator', 2.9516113522744618)]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-214-56d8482f9d34> in <module>()
# ----> 1 print dfNotNull.cptCodes
#
# C:\Users\James\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    2358                 return self[name]
#    2359             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2360                                  (type(self).__name__, name))
#    2361
#    2362     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cptCodes'

# %%
        
        
        
print """
Run Linear Regression w/ Iteartive Feature Selection ****
"""
feature_cols = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
feature_cols = ['Lumbar Radiofrequency', 'Radiofrequency', 'ESI', 'Nerve Block 2', 'Injection', 'Medial Branch Block', '3', '1r', 'Gender', 'F17', 'Age']
feature_cols += ['64640', '63650', '64634', '64480', '64635']
X = dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']



def cross_val_Lin_ITER(X, y):
    
    
    linreg2 = LinearRegression()
   
    
    mean2escores3 = cross_val_score(linreg2 , X, y, cv=5, scoring='mean_squared_error')
    meanAbsScores3= cross_val_score(linreg2 , X, y, cv=5, scoring='mean_absolute_error')
    return (mean2escores3,meanAbsScores3) # return average R2

mean2escorelist = []
for L in range(27, len(feature_cols)+1):
    print L
    print "good score list"
    print mean2escorelist.sort()
    
   
    for subset in itertools.combinations(feature_cols, L):
        
        Subset = list(subset)
        X = dfNotNull[Subset]
        cvScores= cross_val_Lin_ITER(X, y)
        
        mean2escores = cvScores[0]
        mean2escores = np.mean(np.sqrt(-mean2escores))
        meanAbsScores= cvScores[1]
        meanAbsScores= -meanAbsScores.mean()
        
        if mean2escores < 8.89 and meanAbsScores <  6.10:
            mean2escorelist+= [mean2escores]
            
            print subset    
            print "root mean squared error"
            
            print mean2escores
            print "mean Abs Scores"

            print meanAbsScores
            print '\n'
# Out:
# Run Linear Regression w/ Iteartive Feature Selection ****

# %%
print 5

# %%
print "Standar Linear Regression W/ Cross Validation"

cptCodesList = []

feature_cols = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
                '62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17',  '1r', 
                'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
len(feature_cols)
X = dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']
print len(X)
print len(y)
    
    
linreg4 = LinearRegression()


mean2escores3 = cross_val_score(linreg4 , X, y, cv=5, scoring='mean_squared_error')
mean2escores4 = cross_val_score(linreg4 , X, y, cv=5, scoring='mean_absolute_error')

print mean2escores3

mean2escores =np.sqrt(-mean2escores3).mean()
meanAbsScores= -mean2escores4.mean()


print feature_cols
print "mean squared error"           
print mean2escores
print "mean Abs Scores"

print meanAbsScores
print '\n'

print len(feature_cols2)
# Out:
# Standar Linear Regression W/ Cross Validation
# 672
# 672
# [-141.8490452   -93.35778642  -61.82801688  -51.32990826  -55.10773072]
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# 8.80464997546
# mean Abs Scores
# 6.09908443762
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8bf7f3e3a24e> in <module>()
#      33 print '\n'
#      34
# ---> 35 print len(feature_cols2)
#
# NameError: name 'feature_cols2' is not defined

# %%
"Select KBest Linear Regression"

from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
print "Run  regression without scalar and with cross validation xyy"


feature_cols = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
                '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 
                'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
X = dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']
for i in range (1, len(feature_cols)+1):
    #gridsearch with select kbest
    param_grid = dict()
    linreg4 = LinearRegression()
    filter1 = SelectKBest(k=i) # select the best 2 features
    pipe = Pipeline([('anova', filter1), ('lr', linreg4)])
    grid1 = GridSearchCV(pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
    grid2= GridSearchCV(pipe, param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
    tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
    abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
    print grid1.best_estimator_
    mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
    mean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring='mean_absolute_error')


    mean2escores =np.sqrt(-mean2escores3).mean()
    meanAbsScores= mean2escores4
    meanAbsScores= -meanAbsScores.mean()


    print feature_list_creator(tf_features)
    print "mean squared error"
    print mean2escores3.mean()           
    print mean2escores
    print "mean Abs Scores"

    print meanAbsScores
    print '\n'
# Out:
# Run KNN regression without scalar and with cross validation xyy
# Pipeline(steps=[('anova', SelectKBest(k=1, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63661']
# mean squared error
# -279.750803969
# 16.5966379385
# mean Abs Scores
# 10.7864261557
#
#
# Pipeline(steps=[('anova', SelectKBest(k=2, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63688', '63661']
# mean squared error
# -278.878823171
# 16.561937409
# mean Abs Scores
# 10.7524690824
#
#
# Pipeline(steps=[('anova', SelectKBest(k=3, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63685', '63688', '63661']
# mean squared error
# -145.412257869
# 11.9750598623
# mean Abs Scores
# 9.0588324521
#
#
# Pipeline(steps=[('anova', SelectKBest(k=4, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '63685', '63688', '63661']
# mean squared error
# -132.668299062
# 11.4253013324
# mean Abs Scores
# 8.74543356998
#
#
# Pipeline(steps=[('anova', SelectKBest(k=5, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '63685', '63688', '63661', 'Radiofrequency']
# mean squared error
# -90.3214424392
# 9.33226627704
# mean Abs Scores
# 6.60388710037
#
#
# Pipeline(steps=[('anova', SelectKBest(k=6, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -89.625919519
# 9.292193453
# mean Abs Scores
# 6.52536893571
#
#
# Pipeline(steps=[('anova', SelectKBest(k=7, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -88.230960263
# 9.22675341739
# mean Abs Scores
# 6.51649287824
#
#
# Pipeline(steps=[('anova', SelectKBest(k=8, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -88.2767625773
# 9.22871785096
# mean Abs Scores
# 6.51751471272
#
#
# Pipeline(steps=[('anova', SelectKBest(k=9, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.284458162
# 8.95411822603
# mean Abs Scores
# 6.23467155006
#
#
# Pipeline(steps=[('anova', SelectKBest(k=10, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.6033554321
# 8.97086995966
# mean Abs Scores
# 6.24788002875
#
#
# Pipeline(steps=[('anova', SelectKBest(k=11, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64493', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.3394620351
# 8.95353706676
# mean Abs Scores
# 6.23379717762
#
#
# Pipeline(steps=[('anova', SelectKBest(k=12, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.7002949843
# 8.97385722312
# mean Abs Scores
# 6.26107074521
#
#
# Pipeline(steps=[('anova', SelectKBest(k=13, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -84.340719638
# 9.01844622232
# mean Abs Scores
# 6.32123542052
#
#
# Pipeline(steps=[('anova', SelectKBest(k=14, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -85.279635642
# 9.07341965273
# mean Abs Scores
# 6.35424126773
#
#
# Pipeline(steps=[('anova', SelectKBest(k=15, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.6374890959
# 8.98919369011
# mean Abs Scores
# 6.26500668202
#
#
# Pipeline(steps=[('anova', SelectKBest(k=16, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.6075503268
# 8.92619727459
# mean Abs Scores
# 6.22010990977
#
#
# Pipeline(steps=[('anova', SelectKBest(k=17, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.533957582
# 8.90907441255
# mean Abs Scores
# 6.21193906878
#
#
# Pipeline(steps=[('anova', SelectKBest(k=18, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.9365729217
# 8.87247677311
# mean Abs Scores
# 6.17155237326
#
#
# Pipeline(steps=[('anova', SelectKBest(k=19, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.0040818642
# 8.87583358729
# mean Abs Scores
# 6.1612799941
#
#
# Pipeline(steps=[('anova', SelectKBest(k=20, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.8174105954
# 8.86736800967
# mean Abs Scores
# 6.15161499388
#
#
# Pipeline(steps=[('anova', SelectKBest(k=21, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64495', '64633', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.0461724201
# 8.93239685807
# mean Abs Scores
# 6.17905657641
#
#
# Pipeline(steps=[('anova', SelectKBest(k=22, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.819527415
# 8.91915969192
# mean Abs Scores
# 6.18573285597
#
#
# Pipeline(steps=[('anova', SelectKBest(k=23, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.2487564701
# 8.89393028416
# mean Abs Scores
# 6.14132014598
#
#
# Pipeline(steps=[('anova', SelectKBest(k=24, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -82.4381321061
# 8.90394696605
# mean Abs Scores
# 6.13874098559
#
#
# Pipeline(steps=[('anova', SelectKBest(k=25, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -82.8720766547
# 8.93029367463
# mean Abs Scores
# 6.16470452517
#
#
# Pipeline(steps=[('anova', SelectKBest(k=26, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -82.8932016447
# 8.93076965266
# mean Abs Scores
# 6.1739477407
#
#
# Pipeline(steps=[('anova', SelectKBest(k=27, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -84.5155748596
# 9.01494174955
# mean Abs Scores
# 6.26261663353
#
#
# Pipeline(steps=[('anova', SelectKBest(k=28, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -85.9532441123
# 9.10143318857
# mean Abs Scores
# 6.35005650897
#
#
# Pipeline(steps=[('anova', SelectKBest(k=29, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -85.9718380162
# 9.10157269432
# mean Abs Scores
# 6.33212179287
#
#
# Pipeline(steps=[('anova', SelectKBest(k=30, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -6.58298311246e+23
# 512345218819.0
# mean Abs Scores
# 44182364938.7
#
#
# Pipeline(steps=[('anova', SelectKBest(k=31, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -5.0520806005e+24
# 1.33364984523e+12
# mean Abs Scores
# 127767166132.0

# %%
print "Standard SDGC W/ GridSearch"

"Select KBest  Regression"

from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union



feature_cols = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
                '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 
                'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
X = dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']
for i in range (5, len(feature_cols)+1):
    #gridsearch with select kbest
    sgd = SGDRegressor()



    param_grid = {'sgd__loss':['squared_loss'], 
              'sgd__penalty':['none', 'l2', 'l1', 'elasticnet'],
               'sgd__alpha': [1e-4,1e-3,1e-2,1e-1,1,1e1],
              'sgd__n_iter': [1000]
             }
    filter1 = SelectKBest(k=i) # select the best i features
    pipe = Pipeline([('anova', filter1), ('sgd', sgd)])
    
    grid1 = GridSearchCV(pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
    grid2= GridSearchCV(pipe, param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
    tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
    abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
    print grid1.best_estimator_
    mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
    mean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring='mean_absolute_error')


    mean2escores =np.sqrt(-mean2escores3).mean()
    meanAbsScores= mean2escores4
    meanAbsScores= -meanAbsScores.mean()


    print feature_list_creator(tf_features)
    print "mean squared error"
    print mean2escores3.mean()           
    print mean2escores
    print "mean Abs Scores"

    print meanAbsScores
    print '\n'






"""
feature_cols =['64640', '64484', '20605', '63685', '63688', '62311', 
                '62310', '63661',  '64450', '27096', 'Gender', 'Age', 'F17',  '1r', 
                'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']#feature_cols += ['Gender'] #+['F17'] + ['Age'] 
tf= dfNotNull[feature_cols]
X = tf
y = dfNotNull['TotalTimeMin']

sgd = SGDRegressor()



param_grid = {'loss':['squared_loss'], 
              'penalty':['none', 'l2', 'l1', 'elasticnet'],
              'alpha': [1e-4,1e-3,1e-2,1e-1,1,1e1],
              'n_iter': [10,100,1000]
             }

grid2= GridSearchCV(sgd , param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
grid1 = GridSearchCV(sgd, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
grid1.best_estimator_
print 555
mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
mean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring='mean_absolute_error')



mean2escores =np.sqrt(-mean2escores3).mean()
meanAbsScores= mean2escores4
meanAbsScores= -meanAbsScores.mean()


print feature_cols   
print "mean squared error"
print mean2escores3.mean()           
print mean2escores
print "mean Abs Scores"

print meanAbsScores
print '\n'
"""
# Out:
# Standard SDGC W/ GridSearch
# Run KNN regression without scalar and with cross validation xyy
# Pipeline(steps=[('anova', SelectKBest(k=5, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '63685', '63688', '63661', 'Radiofrequency']
# mean squared error
# -89.8936367245
# 9.29970432678
# mean Abs Scores
# 6.58265072754
#
#
# Pipeline(steps=[('anova', SelectKBest(k=6, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -89.2063817121
# 9.26009847669
# mean Abs Scores
# 6.50557913159
#
#
# Pipeline(steps=[('anova', SelectKBest(k=7, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -87.7431628901
# 9.19198709085
# mean Abs Scores
# 6.47508627167
#
#
# Pipeline(steps=[('anova', SelectKBest(k=8, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -87.851679303
# 9.19750685605
# mean Abs Scores
# 6.486941061
#
#
# Pipeline(steps=[('anova', SelectKBest(k=9, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.8069597577
# 8.91884553608
# mean Abs Scores
# 6.18393145549
#
#
# Pipeline(steps=[('anova', SelectKBest(k=10, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.994738003
# 8.92918598769
# mean Abs Scores
# 6.17025325926
#
#
# Pipeline(steps=[('anova', SelectKBest(k=11, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64493', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.8827792573
# 8.9192467498
# mean Abs Scores
# 6.17064623517
#
#
# Pipeline(steps=[('anova', SelectKBest(k=12, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.01, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l1', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.8035460225
# 8.91567641642
# mean Abs Scores
# 6.1607421407
#
#
# Pipeline(steps=[('anova', SelectKBest(k=13, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.3488551512
# 8.9525845542
# mean Abs Scores
# 6.20625636746
#
#
# Pipeline(steps=[('anova', SelectKBest(k=14, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.9388925696
# 8.9915867867
# mean Abs Scores
# 6.23623785704
#
#
# Pipeline(steps=[('anova', SelectKBest(k=15, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.1620220324
# 8.89893367431
# mean Abs Scores
# 6.16133528478
#
#
# Pipeline(steps=[('anova', SelectKBest(k=16, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.7000564891
# 8.87164080146
# mean Abs Scores
# 6.15087974329
#
#
# Pipeline(steps=[('anova', SelectKBest(k=17, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.976247825
# 8.87938679055
# mean Abs Scores
# 6.16048594949
#
#
# Pipeline(steps=[('anova', SelectKBest(k=18, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.6201225271
# 8.85720969081
# mean Abs Scores
# 6.12485401574
#
#
# Pipeline(steps=[('anova', SelectKBest(k=19, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.2605879616
# 8.83518519078
# mean Abs Scores
# 6.08590077015
#
#
# Pipeline(steps=[('anova', SelectKBest(k=20, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.1631316091
# 8.83326201911
# mean Abs Scores
# 6.08627274958
#
#
# Pipeline(steps=[('anova', SelectKBest(k=21, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64495', '64633', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -82.0197245402
# 8.87574257647
# mean Abs Scores
# 6.1095380242
#
#
# Pipeline(steps=[('anova', SelectKBest(k=22, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.9738345887
# 8.8733143068
# mean Abs Scores
# 6.10500200837
#
#
# Pipeline(steps=[('anova', SelectKBest(k=23, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='elasticnet',
#        power_t=0.25, random_state=None, shuffle=True, verbose=0,
#        warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.8764224745
# 8.86627317078
# mean Abs Scores
# 6.09909751815
#
#
# Pipeline(steps=[('anova', SelectKBest(k=24, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.6440468636
# 8.85290328691
# mean Abs Scores
# 6.09480944485
#
#
# Pipeline(steps=[('anova', SelectKBest(k=25, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.8215065792
# 8.86493519808
# mean Abs Scores
# 6.11853530896
#
#
# Pipeline(steps=[('anova', SelectKBest(k=26, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.8720079023
# 8.86623570103
# mean Abs Scores
# 6.11758180147
#
#
# Pipeline(steps=[('anova', SelectKBest(k=27, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.9075655663
# 8.86889590081
# mean Abs Scores
# 6.11643005718
#
#
# Pipeline(steps=[('anova', SelectKBest(k=28, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='elasticnet',
#        power_t=0.25, random_state=None, shuffle=True, verbose=0,
#        warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.4869242811
# 8.84877328426
# mean Abs Scores
# 6.08808825587
#
#
# Pipeline(steps=[('anova', SelectKBest(k=29, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='elasticnet',
#        power_t=0.25, random_state=None, shuffle=True, verbose=0,
#        warm_start=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.5019934263
# 8.85005653751
# mean Abs Scores
# 6.08532106697
#
#
# Pipeline(steps=[('anova', SelectKBest(k=30, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.2308800681
# 8.83604378833
# mean Abs Scores
# 6.08044259297
#
#
# Pipeline(steps=[('anova', SelectKBest(k=31, score_func=<function f_classif at 0x000000000ADDC3C8>)), ('sgd', SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
#        loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
#        random_state=None, shuffle=True, verbose=0, warm_start=False))])
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -81.1987788287
# 8.83485505941
# mean Abs Scores
# 6.08014107388
# '\nfeature_cols =[\'64640\', \'64484\', \'20605\', \'63685\', \'63688\', \'62311\', \n                \'62310\', \'63661\',  \'64450\', \'27096\', \'Gender\', \'Age\', \'F17\',  \'1r\', \n                \'ESI\', \'Lumbar Radiofrequency\', \'Nerve Block 2\', \'Radiofrequency\']#feature_cols += [\'Gender\'] #+[\'F17\'] + [\'Age\'] \ntf= dfNotNull[feature_cols]\nX = tf\ny = dfNotNull[\'TotalTimeMin\']\n\nsgd = SGDRegressor()\n\n\n\nparam_grid = {\'loss\':[\'squared_loss\'], \n              \'penalty\':[\'none\', \'l2\', \'l1\', \'elasticnet\'],\n              \'alpha\': [1e-4,1e-3,1e-2,1e-1,1,1e1],\n              \'n_iter\': [10,100,1000]\n             }\n\ngrid2= GridSearchCV(sgd , param_grid, cv=5, scoring=\'mean_absolute_error\').fit(X,y)\ngrid1 = GridSearchCV(sgd, param_grid, cv=5, scoring=\'mean_squared_error\').fit(X,y)\ngrid1.best_estimator_\nprint 555\nmean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring=\'mean_squared_error\')\nmean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring=\'mean_absolute_error\')\n\n\n\nmean2escores =np.sqrt(-mean2escores3).mean()\nmeanAbsScores= mean2escores4\nmeanAbsScores= -meanAbsScores.mean()\n\n\nprint feature_cols   \nprint "mean squared error"\nprint mean2escores3.mean()           \nprint mean2escores\nprint "mean Abs Scores"\n\nprint meanAbsScores\nprint \'\n\'\n'

# %%
pipe.get_params().keys()
# Out:
# ['sgd__learning_rate',
#  'sgd__alpha',
#  'anova__score_func',
#  'sgd__fit_intercept',
#  'sgd__l1_ratio',
#  'sgd__n_iter',
#  'sgd__penalty',
#  'anova__k',
#  'anova',
#  'sgd__average',
#  'sgd__epsilon',
#  'sgd__random_state',
#  'sgd__power_t',
#  'sgd__warm_start',
#  'steps',
#  'sgd__eta0',
#  'sgd__loss',
#  'sgd',
#  'sgd__verbose',
#  'sgd__shuffle']

# %%
print mean2escores
# Out:
# nan

# %%
print """
Run KNN Regression Cross Val All Feature Combos Piped and non piped Scalar ****
"""


"scaling pipe"
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union

from sklearn.neighbors import KNeighborsRegressor
"Scale values in the DF"   
from sklearn.base import TransformerMixin
#from sklearn import preprocessing

class FeatureScalarTransformer(TransformerMixin):
        def transform(self,X,  **transform_params):
            if 'BMI' in X:
                #X['BMI'] = preprocessing.scale(X['BMI'])
                scal = StandardScaler().fit(X['BMI'])
                X['BMI'] = scal.transform(X['BMI'])
            if 'Age' in X:
                #X['Age']= preprocessing.scale(X['Age'].astype('float'))
                scal = StandardScaler().fit(X['Age'])
                X['Age']=  scal.transform(X['Age'])
            if 'SurgicalHistoryLen' in X:
                #X['SurgicalHistoryLen'] = preprocessing.scale(X['SurgicalHistoryLen'].astype('float')
                scal = StandardScaler().fit(X['SurgicalHistoryLen'])                
                X['SurgicalHistoryLen'] = scal.transform(X['SurgicalHistoryLen'])
            if 'HealthCodesLen' in X:
                #X['HealthCodesLen'] = preprocessing.scale(X['HealthCodesLen'].astype('float'))
                scal = StandardScaler().fit(X['HealthCodesLen'])
                X['HealthCodesLen'] = scal.transform(X['HealthCodesLen'])
            
            
            return X
           

        def fit(self, X, y=None, **fit_params):
            return self
# Out:
# Run KNN Regression Cross Val All Feature Combos Piped and non piped Scalar ****

# %%
def feature_list_creator(tf_features):
    b = str(tf_features).replace('[', 'r').replace("  "," ").replace("\n","").split(" ")
    b =[x for x in b if x != 'r']
    feature_list = []
    for num,i in enumerate(b):
        if 'Tr' in i:
            feature_list += [feature_cols[num]]
        else:
            pass
    return feature_list

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
print "Run KNN regression without scalar and with cross validation xyy"


feature_cols = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
                '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 
                'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
X = dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']
for i in range (1, len(feature_cols)+1):
    #gridsearch with select kbest
    neighbs_k = range(1, 30)
    param_grid = dict(neigh__n_neighbors=neighbs_k )
    neigh = KNeighborsRegressor()
    filter1 = SelectKBest(k=i) # select the best 2 features
    pipe = Pipeline([('anova', filter1), ('neigh', neigh)])
    grid1 = GridSearchCV(pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
    grid2= GridSearchCV(pipe, param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
    tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
    abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
    print grid1.best_estimator_
    mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
    mean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring='mean_absolute_error')


    mean2escores =np.sqrt(-mean2escores3).mean()
    meanAbsScores= mean2escores4
    meanAbsScores= -meanAbsScores.mean()


    print feature_list_creator(tf_features)
    print "mean squared error"
    print mean2escores3.mean()           
    print mean2escores
    print "mean Abs Scores"

    print meanAbsScores
    print '\n'
# Out:
# Run KNN regression without scalar and with cross validation xyy
# Pipeline(steps=[('anova', SelectKBest(k=1, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=9, p=2,
#           weights='uniform'))])
# ['63661']
# mean squared error
# -280.390606365
# 16.6271259022
# mean Abs Scores
# 10.5679049198
#
#
# Pipeline(steps=[('anova', SelectKBest(k=2, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#           weights='uniform'))])
# ['63688', '63661']
# mean squared error
# -279.634881457
# 16.5943045245
# mean Abs Scores
# 10.545590105
#
#
# Pipeline(steps=[('anova', SelectKBest(k=3, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=13, p=2,
#           weights='uniform'))])
# ['63685', '63688', '63661']
# mean squared error
# -148.800510727
# 12.0962554187
# mean Abs Scores
# 9.14432006633
#
#
# Pipeline(steps=[('anova', SelectKBest(k=4, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=13, p=2,
#           weights='uniform'))])
# ['63650', '63685', '63688', '63661']
# mean squared error
# -136.884485266
# 11.5977759272
# mean Abs Scores
# 8.72164524599
#
#
# Pipeline(steps=[('anova', SelectKBest(k=5, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#           weights='uniform'))])
# ['63650', '63685', '63688', '63661', 'Radiofrequency']
# mean squared error
# -90.7491852466
# 9.29687398334
# mean Abs Scores
# 6.58799041828
#
#
# Pipeline(steps=[('anova', SelectKBest(k=6, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#           weights='uniform'))])
# ['63650', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -93.5523855169
# 9.50408983193
# mean Abs Scores
# 6.62337055463
#
#
# Pipeline(steps=[('anova', SelectKBest(k=7, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#           weights='uniform'))])
# ['63650', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -86.7648901327
# 9.05337080542
# mean Abs Scores
# 6.43126294454
#
#
# Pipeline(steps=[('anova', SelectKBest(k=8, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -85.3708057705
# 8.98504719777
# mean Abs Scores
# 6.37585553713
#
#
# Pipeline(steps=[('anova', SelectKBest(k=9, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=11, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.3528947549
# 8.91948101309
# mean Abs Scores
# 6.25185553713
#
#
# Pipeline(steps=[('anova', SelectKBest(k=10, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=11, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -85.8336832824
# 9.08278714072
# mean Abs Scores
# 6.35697544026
#
#
# Pipeline(steps=[('anova', SelectKBest(k=11, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=11, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64493', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -86.4672991334
# 9.11840688914
# mean Abs Scores
# 6.43597172866
#
#
# Pipeline(steps=[('anova', SelectKBest(k=12, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -88.4798234384
# 9.24793546378
# mean Abs Scores
# 6.47095717991
#
#
# Pipeline(steps=[('anova', SelectKBest(k=13, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=11, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -91.0840798761
# 9.39362833512
# mean Abs Scores
# 6.57883712749
#
#
# Pipeline(steps=[('anova', SelectKBest(k=14, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -90.656362963
# 9.36508515232
# mean Abs Scores
# 6.63888738128
#
#
# Pipeline(steps=[('anova', SelectKBest(k=15, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -90.1557250415
# 9.35521391755
# mean Abs Scores
# 6.5886950433
#
#
# Pipeline(steps=[('anova', SelectKBest(k=16, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#           weights='uniform'))])
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -89.731841791
# 9.36552555687
# mean Abs Scores
# 6.5926189565
#
#
# Pipeline(steps=[('anova', SelectKBest(k=17, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#           weights='uniform'))])
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -118.479556329
# 10.5331518666
# mean Abs Scores
# 6.76368554055
#
#
# Pipeline(steps=[('anova', SelectKBest(k=18, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -156.176462825
# 12.3532950469
# mean Abs Scores
# 7.44298507463
#
#
# Pipeline(steps=[('anova', SelectKBest(k=19, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -188.669809978
# 13.7334853504
# mean Abs Scores
# 7.932302377
#
#
# Pipeline(steps=[('anova', SelectKBest(k=20, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -185.575051133
# 13.6212369207
# mean Abs Scores
# 7.95030956329
#
#
# Pipeline(steps=[('anova', SelectKBest(k=21, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64495', '64633', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -190.370554174
# 13.7932080372
# mean Abs Scores
# 7.92606412383
#
#
# Pipeline(steps=[('anova', SelectKBest(k=22, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -189.185630182
# 13.7498211051
# mean Abs Scores
# 7.91374239912
#
#
# Pipeline(steps=[('anova', SelectKBest(k=23, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -192.084758845
# 13.8573735779
# mean Abs Scores
# 7.93802929795
#
#
# Pipeline(steps=[('anova', SelectKBest(k=24, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -194.892987148
# 13.9570635961
# mean Abs Scores
# 7.98572415699
#
#
# Pipeline(steps=[('anova', SelectKBest(k=25, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -199.025990188
# 14.1025444891
# mean Abs Scores
# 8.03601160862
#
#
# Pipeline(steps=[('anova', SelectKBest(k=26, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -191.933049567
# 13.8481143371
# mean Abs Scores
# 7.93339137645
#
#
# Pipeline(steps=[('anova', SelectKBest(k=27, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -192.129589552
# 13.8570180587
# mean Abs Scores
# 7.8971973466
#
#
# Pipeline(steps=[('anova', SelectKBest(k=28, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -191.846594113
# 13.8451784497
# mean Abs Scores
# 7.88637645108
#
#
# Pipeline(steps=[('anova', SelectKBest(k=29, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -192.031964483
# 13.8518184827
# mean Abs Scores
# 7.90202598121
#
#
# Pipeline(steps=[('anova', SelectKBest(k=30, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -188.786421365
# 13.7265296992
# mean Abs Scores
# 7.88783029298
#
#
# Pipeline(steps=[('anova', SelectKBest(k=31, score_func=<function f_classif at 0x000000000A8935F8>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#           weights='uniform'))])
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -188.786421365
# 13.7265296992
# mean Abs Scores
# 7.88783029298

# %%
# Out:
# [16.601157331849141, 16.564657284166742, 11.975498069637041, 11.462100964373942, 9.3326198689542856, 9.2875299925687038, 9.2309420572079954, 9.2308484168332132, 8.953882442671306, 8.9543168177578174, 8.9591426267482746, 8.9932900986076962, 9.0538069959771423, 8.9315335816578276, 8.8981313110326052, 8.9072648561533985, 8.8823691876510935, 8.8469186542471956, 8.8539641699618521, 8.8449464202231649, 8.83014437017974, 8.8363589530468225, 8.8369445055935802, 8.8345589801649709, 8.8345680671214755, 8.8199531678838472, 8.8201269637657322]

# %%
print "Random Forest Grid Search***"

feature_cols =  Procedure4feat + Procedure3feat +ClassFeat + NonScaledContfeat + sigCodesList
feature_cols =['Lumbar Radiofrequency',  'Radiofrequency', 'ESI','Nerve Block 2','Injection','Medial Branch Block' ]#

feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']#

X= dfNotNull[feature_cols]
n_ests = range(1, 20, 2)
#n_ests = range(1, 90, 2)
max_feats = range(1,len(feature_cols)+1)
#max_feats = range(2,13)
param_grid = dict(n_estimators=n_ests,max_features =max_feats)


rfreg = RandomForestRegressor()

grid = GridSearchCV(rfreg, param_grid, cv=5,scoring='mean_squared_error').fit(X,y)

print np.sqrt(-grid.best_score_)
# Out:
# Random Forest Grid Search***
# 10.3295627032

# %%
print "BEST FEATURES FOR RANDOM FOREST GRID SEARCH AND PREDICTIONS"
print grid.best_estimator_
print np.sqrt(-grid.best_score_)
print pandas.DataFrame({'feature':feature_cols, 'importance':grid.best_estimator_.feature_importances_}).sort('importance')
RFPredictions =grid.best_estimator_.predict(X)
# Out:
# BEST FEATURES FOR RANDOM FOREST GRID SEARCH AND PREDICTIONS
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=17, max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=11, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)
# 10.3295627032
#                   feature  importance
# 7                   20605    0.000010
# 3                   64480    0.000033
# 20                  64450    0.000090
# 0                   64640    0.000314
# 29          Nerve Block 2    0.000425
# 19                  64493    0.001027
# 10                  62311    0.001376
# 12                  63661    0.001455
# 18                  64492    0.001488
# 13                  64494    0.001650
# 21                  27096    0.001683
# 11                  62310    0.001717
# 14                  64495    0.001782
# 17                  64491    0.001841
# 16                  64490    0.002239
# 15                  64633    0.003367
# 6                   64484    0.003843
# 24                    F17    0.007243
# 2                   64634    0.008744
# 25                      3    0.009355
# 4                   64635    0.010813
# 5                   64636    0.015734
# 9                   63688    0.018037
# 22                 Gender    0.020236
# 26                     1r    0.021648
# 27                    ESI    0.031910
# 28  Lumbar Radiofrequency    0.041031
# 30         Radiofrequency    0.075750
# 23                    Age    0.152745
# 1                   63650    0.242861
# 8                   63685    0.319554
# C:\Users\James\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
#rfreg = grid.best_estimator
feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']##
rfreg2 = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
           max_features=2, max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=7, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)
       

gridList =[]
for i in range(1,100):
    mean2escores = np.sqrt(-cross_val_score(rfreg2, X ,y, cv=5, scoring='mean_squared_error').mean())
    gridList += [mean2escores]
print np.array(gridList).mean()


#pandas.DataFrame({'feature':feature_cols, 'importance':rfreg.feature_importances_}).sort('importance')
#X_important = rfreg.transform(X, threshold=.01)
#rfreg.oob_score_
# Out:
# 11.1258832782

# %%
"Grid search with cut down features"

print X_important


n_ests = range(1, 29, 2)
n_ests = range(1, 90, 2)
max_feats = range(1,len(X_important[0,])+1)
#max_feats = range(2,13)
param_grid = dict(n_estimators=n_ests,max_features =max_feats)


rfreg = RandomForestRegressor()

gridcut = GridSearchCV(rfreg, param_grid, cv=5,scoring='mean_squared_error').fit(X_important,y)
print np.sqrt(-gridcut.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-37103f5435e1> in <module>()
#       1 "Grid search with cut down features"
#       2
# ----> 3 print X_important
#       4
#       5
#
# NameError: name 'X_important' is not defined

# %%
print" best_features from grid search, cut features"
print gridcut.best_estimator_
print np.sqrt(-gridcut.best_score_)
# Out:
#  best_features from grid search, cut features
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-87e117a12a5a> in <module>()
#       1
#       2 print" best_features from grid search, cut features"
# ----> 3 print gridcut.best_estimator_
#       4 print np.sqrt(-gridcut.best_score_)
#
# NameError: name 'gridcut' is not defined

# %%
"Run Random Forest Again"
max_feats = 7

#max_feats = range(2,13)
param_grid = dict(n_estimators=[41],max_features =[max_feats])
grid = GridSearchCV(rfreg, param_grid, cv=5,scoring='mean_squared_error').fit(X,y)
print np.sqrt(-grid.best_score_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-0248d16d6c92> in <module>()
#       1 "Run Random Forest Again"
#       2 max_feats = 7
# ----> 3 print param_grid
#       4 #max_feats = range(2,13)
#       5 param_grid = dict(n_estimators=[41],max_features =[max_feats])
#
# NameError: name 'param_grid' is not defined

# %%
"My Transformer"

"""
class EnsembleTranformer(TransformerMixin):
        def __init__(self, model, y):
            self.model = model
            self.y = y
        def transform(self,X,  **transform_params):
            
            
            
            return np.array([self.model.predict(X)]).T
            
            
            
            #return X
           
# pipeline = feature union of EnsembleTranformer
        def fit(self, X, y=None, **fit_params):
            
                
                
            
            self.model.fit(X, y)
            return self"""


class EnsembleTranformer(TransformerMixin):
        def __init__(self, model, y):
            self.model = model
            self.y = y
        def transform(self,X,  **transform_params):
            
            
            
            return np.array([self.model.predict(X)]).T
            
            
            
            #return X
           
# pipeline = feature union of EnsembleTranformer
        def fit(self, X, y=None, **fit_params):
            
                
                
            
            self.model.fit(X, y)
            return self

# %%
"LINEAR Ression Ensemble Sinan's"

"Dont Delete!"
"""from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
e = EnsembleTranformer(knn, response)
e.fit_transform(features)"""
"Dont Delete!"


knn = KNeighborsRegressor(n_neighbors=i)





#rf_features = feature_cols

feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
'62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 
'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
#feature_cols = ['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
X =  dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']

#e =EnsembleTranformer(knn, y)
#print e.fit_transform(dfNotNull[knn_features]).shape

linreg =  LinearRegression() 

base = (2,11.5,11.5)
for k in range(1,25):
    
    linreg1 =  LinearRegression()
    linreg =  LinearRegression()
    knn = KNeighborsRegressor(n_neighbors=k)
    pipe = Pipeline([
    ('union', FeatureUnion([
        ('linreg',EnsembleTranformer(linreg, y)),
        ('knn', EnsembleTranformer(knn , y)),
         ])) 
    ,('mdl', linreg1 )
     ])

    mean2escores = np.sqrt(-cross_val_score(pipe, X, y, cv=5, scoring='mean_squared_error')).mean()
    meanabscores = -cross_val_score(pipe, X ,y, cv=5, scoring='mean_absolute_error').mean()
    print k
    print mean2escores
    print meanabscores
    base = (k, mean2escores,meanabscores )
        
        
        
print "Scores here*****"
print base
# Out:
# 1
# 16.0234347479
# 9.38893197115
# 2
# 10.9672083015
# 7.05820083269
# 3
# 9.99039609551
# 6.65357904265
# 4
# 9.30558504102
# 6.24689221615
# 5
# 9.10835909524
# 6.21567542578
# 6
# 8.97927536448
# 6.14847712739
# 7
# 8.96654677066
# 6.13996306404
# 8
# 8.9299500805
# 6.11538550948
# 9
# 8.90623045232
# 6.11435316236
# 10
# 8.89468366889
# 6.11721091383
# 11
# 8.88071078079
# 6.10489587084
# 12
# 8.86910450335
# 6.09391306563
# 13
# 8.8744663204
# 6.10426725287
# 14
# 8.8592295435
# 6.09666717389
# 15
# 8.83421263865
# 6.09005263818
# 16
# 8.83716613818
# 6.08745056714
# 17
# 8.84742574881
# 6.08979179164
# 18
# 8.83126497654
# 6.08438150686
# 19
# 8.83315894539
# 6.09056238189
# 20
# 8.83353083286
# 6.08877644941
# 21
# 8.82502630903
# 6.08333832808
# 22
# 8.82012696377
# 6.08174753072
# 23
# 8.83076633668
# 6.09350185355
# 24
# 8.832911518
# 6.09124783999
# Scores here*****
# (24, 8.8329115180014224, 6.0912478399899541)

# %%
"""





#rf_features = feature_cols

feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
'62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 
'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
#feature_cols = ['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
X =  dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']

#e =EnsembleTranformer(knn, y)
#print e.fit_transform(dfNotNull[knn_features]).shape

linreg =  LinearRegression() 

base = (2,11.5,11.5)

linreg1 =  LinearRegression()
linreg =  LinearRegression()
knn = KNeighborsRegressor(n_neighbors=k)
pipe = Pipeline([
('union', FeatureUnion([
    ('linreg',EnsembleTranformer(linreg, y)),
    ('knn', EnsembleTranformer(knn , y)),
        ])) 
,('mdl', linreg1 )
     ])

mean2escores = np.sqrt(-cross_val_score(pipe, X, y, cv=5, scoring='mean_squared_error')).mean()
meanabscores = -cross_val_score(pipe, X ,y, cv=5, scoring='mean_absolute_error').mean()
print k
print mean2escores
print meanabscores
base = (k, mean2escores,meanabscores )
        
        
        
print "Scores here*****"
print base

"""





feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
'62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 
'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
X = dfNotNull[feature_cols]
y = dfNotNull['TotalTimeMin']

for i in range (1, len(feature_cols)+1):
    
    #gridsearch with select kbest
    #neighbs_k = range(1, 30)
    param_grid = dict()
    knn = KNeighborsRegressor(n_neighbors = 13)
    linreg1 = LinearRegression()
    linreg = LinearRegression()
    SGD = SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
       fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
       loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
       random_state=None, shuffle=True, verbose=0, warm_start=False)
    filter1 = SelectKBest(k=i) # select the best 2 features
    pipe = Pipeline([('anova', filter1), ('union', FeatureUnion([
    ('linreg',EnsembleTranformer(linreg, y)),
    ('knn', EnsembleTranformer(knn , y)),
    ('SGD',EnsembleTranformer(linreg, y)),
        ])) 
    ,('mdl', knn )
     ])
    grid1 = GridSearchCV(pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
    grid2= GridSearchCV(pipe, param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
    tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
    abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
    
    
    
    mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
    

    mean2escores =np.sqrt(-mean2escores3).mean()
    meanAbsScores= mean2escores4
    meanAbsScores= -meanAbsScores.mean()


    print feature_list_creator(tf_features)
    print "mean squared error"
    print mean2escores3.mean()           
    print mean2escores
    print "mean Abs Scores"

    print meanAbsScores
    print '\n'
# Out:
# ['63661']
# mean squared error
# -281.156672783
# 16.6364173406
# mean Abs Scores
# 6.08014107388
#
#
# ['63688', '63661']
# mean squared error
# -280.188546551
# 16.5978107675
# mean Abs Scores
# 6.08014107388
#
#
# ['63685', '63688', '63661']
# mean squared error
# -146.644472248
# 11.9939544028
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '63685', '63688', '63661']
# mean squared error
# -134.709353234
# 11.4787280065
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '63685', '63688', '63661', 'Radiofrequency']
# mean squared error
# -93.0583305694
# 9.42789667572
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -92.3443064755
# 9.41703717517
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -89.6712227161
# 9.27282129652
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -90.1371091943
# 9.29577718352
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -88.399716081
# 9.21311241325
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -88.5754239977
# 9.24536260232
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64493', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -87.1515762411
# 9.17721032257
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64493', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -85.8568780031
# 9.07559193871
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -86.0241138162
# 9.08133796012
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64635', '64636', '64484', '63685', '63688', '63661', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.4868179811
# 8.97346588126
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64633', '64493', '27096', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.6376339865
# 8.91828872664
# mean Abs Scores
# 6.08014107388
#
#
# ['63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -84.4655357009
# 8.96376353475
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -84.4841081901
# 9.01050780557
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64633', '64493', '27096', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.2033149833
# 8.9273913243
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64633', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.1649128454
# 8.92801308737
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64633', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.1128987541
# 8.92230599254
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64633', '64493', '27096', 'Gender', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -83.4940560184
# 8.9605268128
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64633', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -83.3971662398
# 8.95217691701
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '62310', '63661', '64633', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -82.4181286205
# 8.88879247125
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62310', '63661', '64633', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -83.9693459069
# 8.97586528239
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -84.1464999787
# 8.98846989008
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -83.7540536633
# 8.97647795892
# mean Abs Scores
# 6.08014107388
#
#
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# -83.6105581233
# 8.96722752298
# mean Abs Scores
# 6.08014107388

# %%
"""feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
'62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 
'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
mean2escoresFinal =[]
for i in range (1, len(feature_cols)+1):
    #gridsearch with select kbest
    #neighbs_k = range(1, 30)
    param_grid = dict()
    knn = KNeighborsRegressor(n_neighbors = 22)
    linreg1 = LinearRegression()
    linreg = LinearRegression()
    filter1 = SelectKBest(k=i) # select the best 2 features
    pipe = Pipeline([('anova', filter1), ('union', FeatureUnion([
    ('linreg',EnsembleTranformer(linreg, y)),
    ('knn', EnsembleTranformer(knn , y)),
        ])) 
    ,('mdl', linreg1 )
     ])
    grid1 = GridSearchCV(pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
    grid2= GridSearchCV(pipe, param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
    tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
    abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
    mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
    mean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring='mean_absolute_error')


    mean2escores =np.sqrt(-mean2escores3).mean()
   
    mean2escoresFinal += [mean2escores]
    
print mean2escoresFinal
plt.plot(np.arange(1,len(mean2escoresFinal)+1),np.array(mean2escoresFinal))
plt.ylabel('RMSE')
plt.xlabel('# of Features')"""



feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
                '62310', '63661', '64494', '64495', '64633', '64490', '64491', '64492', '64493', '64450', '27096', 
                'Gender', 'AgeScaled', 'F17', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
mean2escoresFinal =[]
for i in range (1, len(feature_cols)+1):
    #gridsearch with select kbest
    #neighbs_k = range(1, 30)
    param_grid = dict()
    knn = KNeighborsRegressor(n_neighbors = 22)
    knn2 = KNeighborsRegressor(n_neighbors = 14)
    linreg1 = LinearRegression()
    linreg = LinearRegression()
    filter1 = SelectKBest(k=i) # select the best 2 features
    pipe = Pipeline([('anova', filter1), ('union', FeatureUnion([
    ('linreg',EnsembleTranformer(linreg, y)),
    ('knn', EnsembleTranformer(knn , y)),
        ])) 
    ,('mdl', knn2 )
     ])
    grid1 = GridSearchCV(pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
    grid2= GridSearchCV(pipe, param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
    tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
    abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
    mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
    mean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring='mean_absolute_error')


    mean2escores =np.sqrt(-mean2escores3).mean()
   
    mean2escoresFinal += [mean2escores]
    
print mean2escoresFinal
plt.plot(np.arange(1,len(mean2escoresFinal)+1),np.array(mean2escoresFinal))
plt.title()
plt.ylabel('RMSE')
plt.xlabel('# of Features')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-407e6d2c0ef1> in <module>()
#      56      ])
#      57     grid1 = GridSearchCV(pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
# ---> 58     grid2= GridSearchCV(pipe, param_grid, cv=5, scoring='mean_absolute_error').fit(X,y)
#      59     tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
#      60     abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\grid_search.pyc in fit(self, X, y)
#     802
#     803         """
# --> 804         return self._fit(X, y, ParameterGrid(self.param_grid))
#     805
#     806
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     551                                     self.fit_params, return_parameters=True,
#     552                                     error_score=self.error_score)
# --> 553                 for parameters in parameter_iterable
#     554                 for train, test in cv)
#     555
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     802             self._iterating = True
#     803
# --> 804             while self.dispatch_one_batch(iterator):
#     805                 pass
#     806
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     660                 return False
#     661             else:
# --> 662                 self._dispatch(tasks)
#     663                 return True
#     664
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     568
#     569         if self._pool is None:
# --> 570             job = ImmediateComputeBatch(batch)
#     571             self._jobs.append(job)
#     572             self.n_dispatched_batches += 1
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __init__(self, batch)
#     181         # Don't delay the application, to avoid keeping the input
#     182         # arguments in memory
# --> 183         self.results = batch()
#     184
#     185     def get(self):
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\cross_validation.pyc in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, error_score)
#    1529             estimator.fit(X_train, **fit_params)
#    1530         else:
# -> 1531             estimator.fit(X_train, y_train, **fit_params)
#    1532
#    1533     except Exception as e:
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\pipeline.pyc in fit(self, X, y, **fit_params)
#     162             the pipeline.
#     163         """
# --> 164         Xt, fit_params = self._pre_transform(X, y, **fit_params)
#     165         self.steps[-1][-1].fit(Xt, y, **fit_params)
#     166         return self
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\pipeline.pyc in _pre_transform(self, X, y, **fit_params)
#     143         for name, transform in self.steps[:-1]:
#     144             if hasattr(transform, "fit_transform"):
# --> 145                 Xt = transform.fit_transform(Xt, y, **fit_params_steps[name])
#     146             else:
#     147                 Xt = transform.fit(Xt, y, **fit_params_steps[name]) \
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\pipeline.pyc in fit_transform(self, X, y, **fit_params)
#     495             delayed(_fit_transform_one)(trans, name, X, y,
#     496                                         self.transformer_weights, **fit_params)
# --> 497             for name, trans in self.transformer_list)
#     498
#     499         Xs, transformers = zip(*result)
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self, iterable)
#     802             self._iterating = True
#     803
# --> 804             while self.dispatch_one_batch(iterator):
#     805                 pass
#     806
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in dispatch_one_batch(self, iterator)
#     660                 return False
#     661             else:
# --> 662                 self._dispatch(tasks)
#     663                 return True
#     664
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in _dispatch(self, batch)
#     568
#     569         if self._pool is None:
# --> 570             job = ImmediateComputeBatch(batch)
#     571             self._jobs.append(job)
#     572             self.n_dispatched_batches += 1
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __init__(self, batch)
#     181         # Don't delay the application, to avoid keeping the input
#     182         # arguments in memory
# --> 183         self.results = batch()
#     184
#     185     def get(self):
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\externals\joblib\parallel.pyc in __call__(self)
#      70
#      71     def __call__(self):
# ---> 72         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#      73
#      74     def __len__(self):
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\pipeline.pyc in _fit_transform_one(transformer, name, X, y, transformer_weights, **fit_params)
#     411             return X_transformed * transformer_weights[name], transformer
#     412     if hasattr(transformer, 'fit_transform'):
# --> 413         X_transformed = transformer.fit_transform(X, y, **fit_params)
#     414         return X_transformed, transformer
#     415     else:
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\base.pyc in fit_transform(self, X, y, **fit_params)
#     456         else:
#     457             # fit method of arity 2 (supervised transformation)
# --> 458             return self.fit(X, y, **fit_params).transform(X)
#     459
#     460
#
# <ipython-input-4-55e8d3648153> in transform(self, X, **transform_params)
#      34
#      35
# ---> 36             return np.array([self.model.predict(X)]).T
#      37
#      38
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\neighbors\regression.pyc in predict(self, X)
#     140             Target values
#     141         """
# --> 142         X = check_array(X, accept_sparse='csr')
#     143
#     144         neigh_dist, neigh_ind = self.kneighbors(X)
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     396                              % (array.ndim, estimator_name))
#     397         if force_all_finite:
# --> 398             _assert_all_finite(array)
#     399
#     400     shape_repr = _shape_repr(array.shape)
#
# C:\Users\James\Anaconda2\lib\site-packages\sklearn\utils\validation.pyc in _assert_all_finite(X)
#      45 def _assert_all_finite(X):
#      46     """Like assert_all_finite, but only for ndarray."""
# ---> 47     X = np.asanyarray(X)
#      48     # First try an O(n) time, O(1) space solution for the common case that
#      49     # everything is finite; fall back to O(n) space np.isfinite to prevent
#
# C:\Users\James\Anaconda2\lib\site-packages\numpy\core\numeric.pyc in asanyarray(a, dtype, order)
#     523
#     524     """
# --> 525     return array(a, dtype, copy=False, order=order, subok=True)
#     526
#     527 def ascontiguousarray(a, dtype=None):
#
# KeyboardInterrupt:

# %%
def RMSEPLOTCReate(start,Feature_Union,Model,ModelName, Title, KNT1, KNT2, feature_cols):
    mean2escoresFinal =[]
    
    for i in range (start, len(feature_cols)+1):
        #gridsearch with select kbest
        #neighbs_k = range(1, 30)
        
        filter1 = SelectKBest(k=i) # select the best 2 features
        
        param_grid = dict()
        
        if Feature_Union == 0:
            
            Pipe =  Pipeline([('anova', filter1)  
                ,('mdl', Model )
                 ])
        else:
            Pipe = Pipeline([('anova', filter1), Feature_Union
                ,('mdl', Model )
             ])
            
        
        
        X = dfNotNull[feature_cols]
        y = dfNotNull['TotalTimeMin']
        grid1 = GridSearchCV(Pipe, param_grid, cv=5, scoring='mean_squared_error').fit(X,y)
        tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
        #abs_features=str(grid2.best_estimator_.named_steps['anova'].get_support())
        mean2escores3 = cross_val_score(grid1.best_estimator_ , X, y, cv=5, scoring='mean_squared_error')
        #mean2escores4 = cross_val_score(grid2.best_estimator_ , X, y, cv=5, scoring='mean_absolute_error')
        
        if i == 9 and "KNN" in ModelName:
            print "Feature 9 best Esitmator"
            print grid1.best_estimator_


        mean2escores =np.sqrt(-mean2escores3).mean()
        if mean2escores > 18:
            
            break
            
        mean2escoresFinal += [mean2escores]
    
    tf_features=str(grid1.best_estimator_.named_steps['anova'].get_support())
    Features =feature_list_creator(tf_features)    
    pp ="RMSE_Graphs\\"+Title + KNT1 + KNT2 +".pdf"
    plt.plot(np.arange(1,len(mean2escoresFinal)+1),np.array(mean2escoresFinal))
    plt.title(Title)
    plt.ylabel('RMSE')
    plt.xlabel('# of Features')
    plt.show()
    plt.savefig(pp, format='pdf')
    return(feature_cols,Pipe, Title, KNT1, KNT2, mean2escoresFinal,Features)

# %%
print "Ensemble with Average Lengths"

feature_cols =['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
'62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 
'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']

y = dfNotNull['TotalTimeMin']
X = dfNotNull[feature_cols]
numFolds = 5
kf = KFold(len(y), numFolds, shuffle=True)
sqrd =[]

for j in range(1,1000):
    
    smlSqrd = []
    for train_indices, test_indices in kf:

                linreg =  LinearRegression()
                
                knn = KNeighborsRegressor(n_neighbors=9)
                features_train = X.T[train_indices];response_train = y[train_indices]
                features_test =  X.T[test_indices];response_test = y[test_indices]


                linreg.fit(features_train.T,response_train)
                predictionsLin = linreg.predict(features_test.T)

                KNNFeatures = ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
                knn.fit(features_train.T[KNNFeatures],response_train)
                predictionsK = knn.predict(features_test.T[KNNFeatures])
                predictions =(predictionsLin*1.35 + predictionsK*.65)/2
                mse =mean_squared_error(predictions, response_test)
                
                smlSqrd += [np.sqrt(mse)]
    
    sqrd += [np.array(smlSqrd).mean()]

print np.array(sqrd).mean()
# Out:
# Ensemble with Average Lengths
# 8.9740845044

# %%
#Formats the inputs and calls the plots 
def call(start,FU, Model , neighs1, neighs2,feature_cols):
    
    Linreg = LinearRegression()
    Linreg1 = LinearRegression()
    KNN = KNeighborsRegressor(n_neighbors = neighs1)
    KNN1 = KNeighborsRegressor(n_neighbors = neighs2)
    SGD =  SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
       fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
       loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
       random_state=None, shuffle=True, verbose=0, warm_start=False)
    SGD1 =  SGDRegressor(alpha=0.001, average=False, epsilon=0.1, eta0=0.01,
       fit_intercept=True, l1_ratio=0.15, learning_rate='invscaling',
       loss='squared_loss', n_iter=1000, penalty='l2', power_t=0.25,
       random_state=None, shuffle=True, verbose=0, warm_start=False)
    
    AlgDict = {'Linreg':Linreg,'Linreg1' : Linreg1,'KNN': KNN,
          'KNN1': KNN1,'SGD1': SGD1,
           'Linreg_KNN': FeatureUnion([
                ('linreg',EnsembleTranformer(Linreg, y)),
                ('knn', EnsembleTranformer(KNN , y)),
            ]),
          'Linreg_KNN_SGD' : FeatureUnion([
                ('linreg',EnsembleTranformer(Linreg, y)),
                ('knn', EnsembleTranformer(KNN , y)),
                ('sgd', EnsembleTranformer(SGD , y)),
            ]),
          'Linreg_SGD' : FeatureUnion([
                ('linreg',EnsembleTranformer(Linreg, y)),
                ('sgd', EnsembleTranformer(SGD , y)),
            ]),
           'KNN_SGD' : FeatureUnion([
                ('knn', EnsembleTranformer(KNN , y)),
                ('sgd', EnsembleTranformer(SGD , y)),
            ])
           }
    

    #Format the neighbors for the Save File title
    if FU == 'Linreg_KNN' or FU == 'Linreg_KNN_SGD' or FU == 'KNN_SGD' or FU == 'KNN':
            KNT1 = "_"+str(neighs1)
    else:
            KNT1 = ''

    if 'KNN' in Model:
            KNT2 = str(neighs2)
            ModelName = "KNN"
    elif 'SGD' in Model:
            KNT2 = str(neighs2)
            ModelName = "SGD"
    else:
            KNT2 = ''
            ModelName = "Linreg"

    #CREATE PLOT TITLE

    if FU == 'Linreg_KNN':
        Title = "Linreg, KNN - " + ModelName + " Ensemble"
    elif FU == 'Linreg_KNN_SGD':
        Title = "Linreg, KNN, SGD - " + ModelName + " Ensemble"
    elif FU == 'Linreg_SGD':
        Title = "Linreg, SGD - " + ModelName + " Ensemble"
    elif FU == 'KNN_SGD':
        Title = "KNN, SGD - " + ModelName + " Ensemble"
    elif FU == 'KNN':
        Title = "KNN"
    elif FU == 'Linreg':
        Title = "Linreg"
    

    FUD = AlgDict[FU]
    Model = AlgDict[Model]
    
    #Map the types of ensmble to the Pipe
    if FU == 'Linreg' or FU == 'KNN':
        Feature_Union = 0
        Model = AlgDict[FU]
    else:
        Feature_Union  = ('union', FUD) 
        
    
    x= RMSEPLOTCReate(start,Feature_Union,Model,ModelName, Title, KNT1, KNT2,feature_cols)
    
    print x[2] +"**********"
    print ""
    print "Features =", x[6]
    print ""
    print "RMSE Best Score:", min(enumerate(x[5]), key=operator.itemgetter(1))
    print ""
    print "RMSE 9 Features Score",x[5][9]
    print ""
    print "RMSE 9 Best 9 Features",x[6][:9]
    print ""
    print ""
    
    print "RMSE 15 Features Score",x[5][15]
    print ""
    print "RMSE 15 Best 15 Features",x[6][:15]
    print ""
    print ""
    print "RMSE full Scores", x[5]
    print ""
    print "If Exists FU KNN # of neighbors =" + x[3]
    print "If Exists Model KNN # of neighbors = " + x[4]
    print ""


feature_cols = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
                '62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'AgeScaled', 'F17',  '1r', 
                'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']


start = 1
FU = 'Linreg_SGD'
Model = 'Linreg1'
neighs1 = 15
neighs2 =14


for i in ['Linreg1']:#,, 'SGD1',]:
    #for j in ['Linreg', 'KNN', 'Linreg_KNN','Linreg_KNN_SGD', 'Linreg_SGD', 'KNN_SGD']:
    for j in ['Linreg','Linreg_KNN','Linreg_KNN_SGD']:#, 'KNN_SGD']:
        print "Neigbs!!!!!!"
        neighs1 = 15
        #neighs2 =k
        print neighs1
        
        FU = j
        Model = i
        call(start,FU, Model , neighs1, neighs2, feature_cols)
# Out:
# Neigbs!!!!!!
# 15
# Linreg**********
#
# Features = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
#
# RMSE Best Score: (19, 8.8197972411344274)
#
# RMSE 9 Features Score 8.95710901981
#
# RMSE 9 Best 9 Features ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685']
#
#
# RMSE 15 Features Score 8.84177160598
#
# RMSE 15 Best 15 Features ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492']
#
#
# RMSE full Scores [16.596637938461605, 16.561937409015833, 11.975059862318847, 11.425301332422944, 9.3322662770383555, 9.2921934529977612, 9.2267534173853871, 9.2287178509593861, 8.9541182260331986, 8.9571090198089429, 8.9595928961971101, 9.0221777215791299, 9.0170501316285669, 8.8967406145333996, 8.8921442156182593, 8.8417716059791864, 8.8246734656097132, 8.8367698658331726, 8.8280055961241359, 8.8197972411344274, 8.8282807818218387, 8.8919347052404749, 8.9956678294541526, 8.9902123810145333]
#
# If Exists FU KNN # of neighbors =
# If Exists Model KNN # of neighbors =
#
# Neigbs!!!!!!
# 15
# Linreg, KNN - Linreg Ensemble**********
#
# Features = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
#
# RMSE Best Score: (15, 8.8852591108500363)
#
# RMSE 9 Features Score 8.94975824603
#
# RMSE 9 Best 9 Features ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685']
#
#
# RMSE 15 Features Score 8.88525911085
#
# RMSE 15 Best 15 Features ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492']
#
#
# RMSE full Scores [16.599759368154132, 16.559446809366673, 11.976421041819643, 11.5035258411769, 9.3226684340281487, 9.2872643247838802, 9.2340396453883073, 9.2348803901096836, 8.9536379610310242, 8.9497582460263612, 8.9478240069945354, 9.0277088134305679, 9.0121385663106146, 8.9300627669229105, 8.966602157532618, 8.8852591108500363, 8.951008146592466, 8.9659271446089939, 8.9632116922511464, 8.9466913621856641, 8.9238983696133083, 8.9391034527594773, 9.0287136935852867, 9.0255960040142433]
#
# If Exists FU KNN # of neighbors =_15
# If Exists Model KNN # of neighbors =
#
# Neigbs!!!!!!
# 15
# Linreg, KNN, SGD - Linreg Ensemble**********
#
# Features = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '27096', 'Gender', 'AgeScaled', 'F17', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
#
# RMSE Best Score: (10, 8.937511074141554)
#
# RMSE 9 Features Score 8.94628356804
#
# RMSE 9 Best 9 Features ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685']
#
#
# RMSE 15 Features Score 8.95367397223
#
# RMSE 15 Best 15 Features ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492']
#
#
# RMSE full Scores [16.595264058663556, 16.559582285452841, 11.961662318370369, 11.548731151933133, 9.3152714285947571, 9.2773557546504613, 9.2545079933944461, 9.2396162884993203, 8.9497796956432314, 8.9462835680411352, 8.937511074141554, 9.0701651379097825, 9.0305076771075381, 8.9465455186459604, 9.0670523292312559, 8.9536739722261913, 9.0235312705490269, 8.9920869373861905, 8.9769799257365968, 8.9649330388027657, 8.9579433936602069, 9.0059992440721413, 9.0332999061037658, 9.0589361352996498]
#
# If Exists FU KNN # of neighbors =_15
# If Exists Model KNN # of neighbors =

# %%
print len(dfNotNull)
# Out:
# 672

# %%
"Predict on Out of Sample Data"

print predictions
pipe.fit
dfOOS = pandas.read_csv('OutOS.csv')
X = dfOOS[knn_features]
y = dfOOS['TotalTimeMin']
OutOfSamplePredictions = linreg.predict()
# Out:
# [ 23.68794299  96.72085827  29.53561915  28.87758398  22.23040777
#   21.02400286  40.6248474   40.6248474   40.6248474   21.02400286
#   42.48928747  41.8312523   22.23040777  42.48928747  36.10109435
#   26.61548743  27.67117907  29.53561915  22.88844294  42.48928747
#   42.48928747  42.48928747  29.53561915  28.87758398  42.48928747
#   42.48928747  27.82189234  22.88844294  27.67117907  40.6248474
#   96.72085827  21.02400286  29.53561915  22.88844294  42.48928747
#   26.61548743  26.61548743  42.48928747  42.48928747  29.53561915
#   40.6248474   40.6248474   21.02400286  27.67117907  42.48928747
#   29.53561915  27.82189234  42.48928747  41.8312523   42.48928747
#   22.88844294  28.47992751  27.82189234  22.23040777  34.23665427
#   40.6248474   21.02400286  42.48928747  41.8312523   22.23040777
#   98.58529835  42.48928747  29.53561915  41.8312523   42.48928747
#   26.61548743  40.6248474   21.02400286  96.72085827  42.48928747
#   22.88844294  41.8312523   28.47992751  98.58529835  41.8312523
#   21.02400286  34.23665427  22.88844294  28.47992751  29.53561915
#   29.53561915  27.82189234  21.02400286  21.02400286  22.23040777
#   41.8312523   29.53561915  22.88844294  41.8312523   22.88844294
#   42.48928747  22.88844294  22.88844294  27.82189234  21.02400286
#   96.72085827  21.02400286  28.87758398  35.44305918  22.88844294
#   28.87758398  42.48928747  28.87758398  28.87758398  40.6248474
#   27.67117907  27.67117907  21.02400286  36.10109435  25.55238307
#   22.88844294  29.53561915  28.87758398  41.8312523   22.88844294
#   40.6248474   23.68794299  27.67117907  22.88844294  29.53561915
#   22.88844294  42.48928747  22.88844294  26.61548743  26.61548743
#   26.61548743  22.88844294  28.87758398  42.48928747  29.53561915
#   22.88844294  29.53561915  22.88844294  42.48928747  29.53561915
#   40.6248474 ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-156-3dcfd9e32652> in <module>()
#       4 pipe.fit
#       5 dfOOS = pandas.read_csv('OutOS.csv')
# ----> 6 X = dfOOS[knn_features]
#       7 y = dfOOS['TotalTimeMin']
#       8 OutOfSamplePredictions = linreg.predict()
#
# NameError: name 'knn_features' is not defined

# %%
print "Best Algorithms Best Scores!!!"

print """

Lingreg - no cpt codes deleted**********

[-141.8490452   -93.35778642  -61.82801688  -51.32990826  -55.10773072]
['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
mean squared error
8.80464997546
mean Abs Scores
6.09908443762


Linreg - Stepwise with select K-Best*************

Pipeline(steps=[('anova', SelectKBest(k=19, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
mean squared error
-81.8369856139
8.86837633425
mean Abs Scores
6.14019789195

Linreg - Stepwise with select K-Best simpler but w/ comparable performance*************
Pipeline(steps=[('anova', SelectKBest(k=18, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
mean squared error
-81.9365729217
8.87247677311
mean Abs Scores
6.17155237326

Linreg - Stepwise with select K-Best Even simpler, only 9 features! but w/ comparable performance*************
Pipeline(steps=[('anova', SelectKBest(k=9, score_func=<function f_classif at 0x000000000A934668>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
          metric_params=None, n_jobs=1, n_neighbors=11, p=2,
          weights='uniform'))])
['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
mean squared error
-83.3528947549
8.91948101309
mean Abs Scores
6.25185553713




Lingreg - **********

['Lumbar Radiofrequency', 'Radiofrequency', 'ESI', 'Nerve Block 2', 'Injection', 'Medial Branch Block', '3', '1r', 'Gender', 'F17', 'Age']
mean squared error
9.98563469287
mean Abs Scores
6.40693830594








RandomForest Mean of 100 Itearations ********************
feature_cols =['Lumbar Radiofrequency',  'Radiofrequency', 'ESI','Nerve Block 2','Injection','Medial Branch Block' ]##
rfreg2 = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
           max_features=2, max_leaf_nodes=None, min_samples_leaf=1,
           min_samples_split=2, min_weight_fraction_leaf=0.0,
           n_estimators=7, n_jobs=1, oob_score=False, random_state=None,
           verbose=0, warm_start=False)

root mean squared error
10.2626357568




"get null scores************"
Total Average Null:
17.3521970207
11.1181800916

Procedure Average Null:
10.2979764338
6.56061055948


LINREG - Select KBest  *****************

['Lumbar Radiofrequency', 'Spinal Cord Stimulator', 'Lumbar ESI', 'Radiofrequency', 'ESI', 'Spinal Cord Stimulator 2']

Root mean squared error:
10.3549488744
Mean Abs Scores:
6.58723506741


Ensemble - KNN and Linreg, ensembled by linreg *******************
KNN features = ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
LingerFeatures = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', 
'62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r', 
'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']

Neighbors = 22
8.82012696377
6.08174753072







KNN
Pipeline(steps=[('anova', SelectKBest(k=8, score_func=<function f_classif at 0x000000000A934668>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
          metric_params=None, n_jobs=1, n_neighbors=12, p=2,
          weights='uniform'))])
          
['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
mean squared error
-85.3708057705
8.98504719777
mean Abs Scores
6.37585553713




Best Select Knn enemble

14 - 16.701090131478189, 16.67465530490216, 12.016567903236361, 11.492266264170976, 9.44732366364169, 9.4121308219127826, 9.3849997234646878, 9.3807695363951407, 9.1149238699650397, 9.2109388160485288, 9.3264846503283803, 9.0630729484270702, 9.0908347552785553, 9.003595136087915, 9.005505856815363, 8.8088782661242284, 8.9249534892496207, 8.8350301701324163, 8.8428685686560637, 8.891858353943574, 8.8565601249147488, 8.8802009771557842, 8.9053583070795845, 8.8779425585851808, 8.8245891248932331, 8.8095037928242448, 8.8046994989065634]


"""
# Out:
# Best Algorithms Best Scores!!!
#
#
# Lingreg - no cpt codes deleted**********
#
# [-141.8490452   -93.35778642  -61.82801688  -51.32990826  -55.10773072]
# ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311', '62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '1r', 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
# mean squared error
# 8.80464997546
# mean Abs Scores
# 6.09908443762
#
#
# Linreg - Stepwise with select K-Best*************
#
# Pipeline(steps=[('anova', SelectKBest(k=19, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', 'Age', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.8369856139
# 8.86837633425
# mean Abs Scores
# 6.14019789195
#
# Linreg - Stepwise with select K-Best simpler but w/ comparable performance*************
# Pipeline(steps=[('anova', SelectKBest(k=18, score_func=<function f_classif at 0x000000000AD405F8>)), ('lr', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])
# ['64640', '63650', '64634', '64635', '64636', '64484', '63685', '63688', '63661', '64494', '64633', '64493', '27096', '3', '1r', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -81.9365729217
# 8.87247677311
# mean Abs Scores
# 6.17155237326
#
# Linreg - Stepwise with select K-Best Even simpler, only 9 features! but w/ comparable performance*************
# Pipeline(steps=[('anova', SelectKBest(k=9, score_func=<function f_classif at 0x000000000A934668>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=11, p=2,
#           weights='uniform'))])
# ['63650', '64635', '64636', '63685', '63688', '63661', 'ESI', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -83.3528947549
# 8.91948101309
# mean Abs Scores
# 6.25185553713
#
#
#
#
# Lingreg - **********
#
# ['Lumbar Radiofrequency', 'Radiofrequency', 'ESI', 'Nerve Block 2', 'Injection', 'Medial Branch Block', '3', '1r', 'Gender', 'F17', 'Age']
# mean squared error
# 9.98563469287
# mean Abs Scores
# 6.40693830594
#
#
#
#
#
#
#
#
# RandomForest Mean of 100 Itearations ********************
# feature_cols =['Lumbar Radiofrequency',  'Radiofrequency', 'ESI','Nerve Block 2','Injection','Medial Branch Block' ]##
# rfreg2 = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features=2, max_leaf_nodes=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=7, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)
#
# root mean squared error
# 10.2626357568
#
#
#
#
# "get null scores************"
# Total Average Null:
# 17.3521970207
# 11.1181800916
#
# Procedure Average Null:
# 10.2979764338
# 6.56061055948
#
#
# LINREG - Select KBest  *****************
#
# ['Lumbar Radiofrequency', 'Spinal Cord Stimulator', 'Lumbar ESI', 'Radiofrequency', 'ESI', 'Spinal Cord Stimulator 2']
#
# Root mean squared error:
# 10.3549488744
# Mean Abs Scores:
# 6.58723506741
#
#
# Ensemble - KNN and Linreg, ensembled by linreg *******************
# KNN features = ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# LingerFeatures = ['64640', '63650', '64634', '64480', '64635', '64636', '64484', '20605', '63685', '63688', '62311',
# '62310', '63661', '64633', '64492', '64493', '64450', '27096', 'Gender', 'Age', 'F17', '3', '1r',
# 'ESI', 'Lumbar Radiofrequency', 'Nerve Block 2', 'Radiofrequency']
#
# Neighbors = 22
# 8.82012696377
# 6.08174753072
#
#
#
#
#
#
#
# KNN
# Pipeline(steps=[('anova', SelectKBest(k=8, score_func=<function f_classif at 0x000000000A934668>)), ('neigh', KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=12, p=2,
#           weights='uniform'))])
#
# ['63650', '64635', '64636', '63685', '63688', '63661', 'Lumbar Radiofrequency', 'Radiofrequency']
# mean squared error
# -85.3708057705
# 8.98504719777
# mean Abs Scores
# 6.37585553713
